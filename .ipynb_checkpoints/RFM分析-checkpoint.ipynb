# %%
#import modules
import pandas as pd # for dataframes
import matplotlib.pyplot as plt # for plotting graphs
import seaborn as sns # for plotting graphs
import datetime as dt
import numpy as np
from sklearn import cluster, datasets #for k-means


# go to file directory

# %%
df = pd.read_csv("user_payment.csv", index_col=0)
df.head()
# Out:
#         UID         payment_date  amount  YEAR  MONTH  DAY
# 0   3753824  2019-11-21 07:54:38     450  2018      9   21
# 3   3884784  2019-02-12 11:47:55      50  2017     12   13
# 4   3884784  2019-02-12 11:53:03      50  2017     12   13
# 9   3911344  2018-07-28 22:52:04     400  2017      5   28
# 11  3911344  2018-07-30 06:30:56     400  2017      5   30

# %%
df.columns = ["UID", "trans_date","tran_amount","YEAR","MONTH","DAY"] #改成英文
df['trans_date'] = pd.to_datetime(df['trans_date']) #object to datetime
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12281 entries, 0 to 31695
# Data columns (total 6 columns):
# UID            12281 non-null int64
# trans_date     12281 non-null datetime64[ns]
# tran_amount    12281 non-null int64
# YEAR           12281 non-null int64
# MONTH          12281 non-null int64
# DAY            12281 non-null int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 671.6 KB

# %%
sd = dt.datetime(2019,12,1)
df['hist']=sd - df['trans_date']
df['hist'].astype('timedelta64[D]')
df['hist']=(df['hist'] / np.timedelta64(1, 'D'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12281 entries, 0 to 31695
# Data columns (total 7 columns):
# UID            12281 non-null int64
# trans_date     12281 non-null datetime64[ns]
# tran_amount    12281 non-null int64
# YEAR           12281 non-null int64
# MONTH          12281 non-null int64
# DAY            12281 non-null int64
# hist           12281 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(5)
# memory usage: 767.6 KB

# %%
df.trans_date.describe()
# Out:
# count                   12281
# unique                  12087
# top       2019-05-09 00:26:07
# freq                        2
# first     2018-03-03 08:44:49
# last      2019-11-30 19:31:35
# Name: trans_date, dtype: object

# %%
rfmTable = df.groupby('UID').agg({'hist': lambda x:x.min(),                   # Recency
                                  'UID': lambda x: len(x),            # Frequency
                                  'tran_amount': lambda x: x.sum()})          # Monetary Value

rfmTable.rename(columns={'hist': 'recency', 
                         'UID': 'frequency', 
                         'tran_amount': 'monetary_value'}, inplace=True)

# %%
rfmTable.head()
# Out:
#             recency  frequency  monetary_value
# UID
# 1341104   56.877627         26           10950
# 1361552   23.383009          2            1000
# 1368368  102.591273         23            3300
# 1369904  213.786331          3            1150
# 1374736  448.009271          1             300

# %%
rfmTable.describe()
# Out:
#            recency    frequency  monetary_value
# count  1078.000000  1078.000000     1078.000000
# mean    119.851495    11.392393     3637.333024
# std     155.116141    16.971904     5582.226163
# min       0.186400     1.000000       25.000000
# 25%      22.600506     2.000000      700.000000
# 50%      49.891163     6.000000     1750.000000
# 75%     151.271369    13.750000     4240.000000
# max     632.830498   176.000000    68500.000000

# %%
rfmTable.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1078 entries, 1341104 to 45484616
# Data columns (total 3 columns):
# recency           1078 non-null float64
# frequency         1078 non-null int64
# monetary_value    1078 non-null int64
# dtypes: float64(1), int64(2)
# memory usage: 33.7 KB

# %%
quartiles = rfmTable.quantile(q=[0.25,0.50,0.75])
print(quartiles, type(quartiles))
# Out:
#          recency  frequency  monetary_value
# 0.25   22.600506       2.00           700.0
# 0.50   49.891163       6.00          1750.0
# 0.75  151.271369      13.75          4240.0 <class 'pandas.core.frame.DataFrame'>

# %%
## for Recency 
def RClass(x,p,d):
    if x <= d[p][0.5]:
        return 0
    else:
        return 1
    
## for Frequency and Monetary value 
def FMClass(x,p,d):
    if x <= d[p][0.5]:
        return 1
    else:
        return 0

# %%
rfmSeg = rfmTable
rfmSeg['R_Mean'] = rfmSeg['recency'].apply(RClass, args=('recency',quartiles,))
rfmSeg['F_Mean'] = rfmSeg['frequency'].apply(FMClass, args=('frequency',quartiles,))
rfmSeg['M_Mean'] = rfmSeg['monetary_value'].apply(FMClass, args=('monetary_value',quartiles,))

# %%
def playerClassify(a,b):
    val = a
    if val == "111":
        rank = 1
    elif val == "110":
        rank = 2
    elif val == "101":
        rank = 3
    elif val == "011":
        rank = 4    
    elif val == "100":
        rank = 5    
    elif val == "010":
        rank = 6    
    elif val == "001":
        rank = 7    
    else:
        rank = 8 
    return rank
        
rfmPlayerSegment = rfmSeg    
rfmPlayerSegment['Score'] = rfmPlayerSegment.R_Mean.map(str) \
                            + rfmSeg.F_Mean.map(str) \
                            + rfmSeg.M_Mean.map(str)

# %%
rfmPlayerSegment['Rank'] = rfmPlayerSegment['Score'].apply(playerClassify, args=('Score',))
rfmPlayerSegment.head()
# Out:
#             recency  frequency  monetary_value  R_Mean  F_Mean  M_Mean Score  \
# UID
# 1341104   56.877627         26           10950       1       0       0   100
# 1361552   23.383009          2            1000       0       1       1   011
# 1368368  102.591273         23            3300       1       0       0   100
# 1369904  213.786331          3            1150       1       1       1   111
# 1374736  448.009271          1             300       1       1       1   111
#
#          Rank
# UID
# 1341104     5
# 1361552     4
# 1368368     5
# 1369904     1
# 1374736     1

# %%
rfmPlayerSegment.to_csv("rfm_customer_segment.csv")

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(rfmTable.recency, rfmTable.frequency, rfmTable.monetary_value, s=50)

ax.set_xlabel('Recency')
ax.set_ylabel('Frequency')
ax.set_zlabel('Monetary')
# Out:
# Text(0.5, 0, 'Monetary')
